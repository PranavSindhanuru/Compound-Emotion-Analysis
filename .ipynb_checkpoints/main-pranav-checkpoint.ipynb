# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Installing collected packages: keras
# Successfully installed keras-2.10.0
# WARNING: You are using pip version 20.1.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'e:\my_projects\spt2\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.10.0-cp37-cp37m-win_amd64.whl (455.9 MB)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.50.0-cp37-cp37m-win_amd64.whl (3.6 MB)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Collecting numpy>=1.20
#   Using cached numpy-1.21.6-cp37-cp37m-win_amd64.whl (14.0 MB)
# Requirement already satisfied: packaging in e:\my_projects\spt2\lib\site-packages (from tensorflow) (21.3)
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Requirement already satisfied: six>=1.12.0 in e:\my_projects\spt2\lib\site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.1.0-py3-none-any.whl (5.8 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp37-cp37m-win_amd64.whl (2.6 MB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.14.1-cp37-cp37m-win_amd64.whl (35 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.27.0-cp37-cp37m-win_amd64.whl (1.5 MB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: setuptools in e:\my_projects\spt2\lib\site-packages (from tensorflow) (47.1.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in e:\my_projects\spt2\lib\site-packages (from tensorflow) (2.10.0)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp37-cp37m-win_amd64.whl (896 kB)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.10.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in e:\my_projects\spt2\lib\site-packages (from tensorflow) (4.4.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.14.1-py2.py3-none-any.whl (175 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting wheel>=0.26
#   Downloading wheel-0.38.4-py3-none-any.whl (36 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in e:\my_projects\spt2\lib\site-packages (from packaging->tensorflow) (3.0.9)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: idna<4,>=2.5 in e:\my_projects\spt2\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.9.24-py3-none-any.whl (161 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in e:\my_projects\spt2\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\my_projects\spt2\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting pyasn1>=0.1.3
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: zipp>=0.5 in e:\my_projects\spt2\lib\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.10.0)
# Installing collected packages: tensorflow-estimator, grpcio, pyasn1, rsa, pyasn1-modules, cachetools, google-auth, oauthlib, charset-normalizer, urllib3, certifi, requests, requests-oauthlib, google-auth-oauthlib, absl-py, protobuf, numpy, tensorboard-plugin-wit, wheel, markdown, tensorboard-data-server, werkzeug, tensorboard, libclang, termcolor, h5py, astunparse, wrapt, tensorflow-io-gcs-filesystem, keras-preprocessing, google-pasta, gast, opt-einsum, flatbuffers, tensorflow
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 certifi-2022.9.24 charset-normalizer-2.1.1 flatbuffers-22.10.26 gast-0.4.0 google-auth-2.14.1 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.50.0 h5py-3.7.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 numpy-1.21.6 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.27.0 termcolor-2.1.0 urllib3-1.26.12 werkzeug-2.2.2 wheel-0.38.4 wrapt-1.14.1
# WARNING: You are using pip version 20.1.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'e:\my_projects\spt2\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install pillow
# Out:
# Collecting pillow
#   Downloading Pillow-9.3.0-1-cp37-cp37m-win_amd64.whl (2.5 MB)
# Installing collected packages: pillow
# Successfully installed pillow-9.3.0
# WARNING: You are using pip version 20.1.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'e:\my_projects\spt2\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: numpy>=1.14.5; python_version >= "3.7" in e:\my_projects\spt2\lib\site-packages (from opencv-python) (1.21.6)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# WARNING: You are using pip version 20.1.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'e:\my_projects\spt2\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in e:\my_projects\spt2\lib\site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in e:\my_projects\spt2\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in e:\my_projects\spt2\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in e:\my_projects\spt2\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in e:\my_projects\spt2\lib\site-packages (from matplotlib) (1.21.6)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp37-cp37m-win_amd64.whl (54 kB)
# Requirement already satisfied: six>=1.5 in e:\my_projects\spt2\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in e:\my_projects\spt2\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (4.4.0)
# Installing collected packages: cycler, fonttools, kiwisolver, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.5.3
# WARNING: You are using pip version 20.1.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'e:\my_projects\spt2\scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# _______________________________________________________________________________

# %%
import tensorflow as tf
from PIL import Image

# %%
img = tf.keras.preprocessing.image.img_to_array(r"1.JPG")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7844\739900964.py in <module>
# ----> 1 img = tf.keras.preprocessing.image.img_to_array(r"1.JPG")
#
# e:\my_projects\spt2\lib\site-packages\keras\utils\image_utils.py in img_to_array(img, data_format, dtype)
#     322     # or (channel, height, width)
#     323     # but original PIL image has format (width, height, channel)
# --> 324     x = np.asarray(img, dtype=dtype)
#     325     if len(x.shape) == 3:
#     326         if data_format == "channels_first":
#
# ValueError: could not convert string to float: '1.JPG'

# %%
import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('1.JPG')
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img, interpolation='nearest')
plt.show()

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 253, 255],
#         [252, 252, 254],
#         [251, 251, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [251, 251, 253],
#         [253, 253, 255],
#         [254, 254, 255]],
#
#        ...,
#
#        [[  9,  29, 115],
#         [  7,  27, 113],
#         [  5,  26, 109],
#         ...,
#         [  7,  28, 117],
#         [  6,  27, 116],
#         [  6,  26, 113]],
#
#        [[  9,  29, 115],
#         [  7,  27, 113],
#         [  4,  25, 108],
#         ...,
#         [ 10,  31, 120],
#         [  9,  30, 119],
#         [  8,  28, 117]],
#
#        [[  8,  28, 114],
#         [  6,  26, 112],
#         [  4,  25, 108],
#         ...,
#         [ 14,  35, 126],
#         [ 12,  33, 122],
#         [ 11,  31, 120]]], dtype=uint8)
